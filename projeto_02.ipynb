# %% [markdown]
# # Projeto 02
#
# ### Automatizando tarefas com Python
# #### Bibliotecas 'pyautogui' 'yfinance' 'pyperclipe' 'matplotlib'
#
#
# - Buscar informações de uma determinada ação
# - Criar as análises solicitadas
#     - Cotação Máxima
#     - Cotação Mínima
#     - Preço Médio
# - Enviar um e-mail para o gestor

# %% [markdown]
# #### Buscar as informações de uma determinada ação
# - bibliotecas 'yfinance' e 'matplotlib'

# %%
# importando yfinance

import yfinance

# %%
ticker = input("Digite o código da ação: ")

dados = yfinance.Ticker(ticker).history(start="2020-01-01", end="2020-12-31")

fechamento = dados.Close
dados
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-01-02 00:00:00-03:00  19.803215  20.033357  19.736400  19.970253
# 2020-01-03 00:00:00-03:00  19.710419  20.011087  19.617620  19.936848
# 2020-01-06 00:00:00-03:00  19.821778  19.821778  19.469143  19.673300
# 2020-01-07 00:00:00-03:00  19.673304  19.684440  19.409757  19.524826
# 2020-01-08 00:00:00-03:00  19.584213  19.669589  19.316954  19.346649
# ...                              ...        ...        ...        ...
# 2020-12-22 00:00:00-03:00  14.727945  15.005977  14.673883  14.785869
# 2020-12-23 00:00:00-03:00  14.893989  15.129543  14.778143  15.029142
# 2020-12-28 00:00:00-03:00  15.183606  15.272422  15.137268  15.195190
# 2020-12-29 00:00:00-03:00  15.253114  15.291729  15.040729  15.106375
# 2020-12-30 00:00:00-03:00  15.168163  15.195194  14.928748  14.982809
#
#                              Volume  Dividends  Stock Splits
# Date
# 2020-01-02 00:00:00-03:00  26319800        0.0           0.0
# 2020-01-03 00:00:00-03:00  18930800        0.0           0.0
# 2020-01-06 00:00:00-03:00  19999800        0.0           0.0
# 2020-01-07 00:00:00-03:00  21277000        0.0           0.0
# 2020-01-08 00:00:00-03:00  42937200        0.0           0.0
# ...                             ...        ...           ...
# 2020-12-22 00:00:00-03:00  21540800        0.0           0.0
# 2020-12-23 00:00:00-03:00  18352600        0.0           0.0
# 2020-12-28 00:00:00-03:00  15154400        0.0           0.0
# 2020-12-29 00:00:00-03:00  14602800        0.0           0.0
# 2020-12-30 00:00:00-03:00  17188000        0.0           0.0
#
# [248 rows x 7 columns]

# %% [markdown]
# #### Criar as análises solicitadas
# - Cotação Máxima
# - Cotação Mínima
# - Preço Médio
# - round estabelece o número de casasa decimais ou arredonamento

# %%
maxima = round(fechamento.max(),2)
minimo = round(fechamento.min(), 2)
preco_medio = round(fechamento.mean(), 2)

print(maxima)
print(minimo)
print(preco_medio)
# Out:
# 19.97
# 8.33
# 13.36

# %% [markdown]
# #### Enviar o e-mail automaticamente
#
# - Abrir o navegador e ir para o Gmail
# - Clicar no botão escrever
# - Selecionar o destinatário e teclar TAB
# - Digitar o assunto e clicar TAB
# - Escrever a mensagem
# - Clicar no Botão Enviar
#
# Bibliotecas 'pyautogui' 'pyperclip' "webbrowser'

# %%
import pyautogui
import pyperclip
import webbrowser
import time

destinatario = "pimpao775@gmail.com"
assunto = f"Dados do Relatório da Ação {ticker}"

mensagem = f"""Rafael 
Seguem as análises solicitadas da ação {ticker}:

Cotação Máxima: R$ {maxima}
Cotação Mínima: R$ {minimo}
Preço Médio: R$ {preco_medio}
Atenciosamente"""

# abrir o navegador e ir para o Gmail

webbrowser.open("www.gmail.com")
time.sleep(10)

# configurando uma pausa para carregar os itens
pyautogui.PAUSE = 5 

# clicar no botão escrever

pyautogui.click(x=98, y=219)

# digitar o e-mail o destinatário e clicar TAB

pyperclip.copy(destinatario)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#digitar o assunto do e-mail e clicar tab

pyperclip.copy(assunto)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")              

# digitar a mensagem do e-mail 

pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl","v")

#clicar no botão enviar 

pyautogui.click(x=215, y=978)

# fechando o Gmail

pyautogui.click(x=732, y=18)
